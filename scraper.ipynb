# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen, Request
import requests
import json
import time
import re

# %% [markdown]
# ### SCRAPER FUNCTIONS

# %%
def get_league_html(session, league, season, window):
    """
    HTML page response
    """
    URL_LEAGUE = "https://www.transfermarkt.com/premier-league/transfers/wettbewerb/{league}/plus/?saison_id={season}&s_w={window}"
    
    scrape_url = URL_LEAGUE.format(
        league=league,
        season=season,
        window=window
    )
    
    print("URL")
    print(scrape_url)

    resp = session.get(scrape_url)
    
    print("RESP")
    print(resp)

    return BeautifulSoup(resp.text)

# %%
def parse_team_id_from_url(url):
    """
    Helper to prase team id from URL
    """
    if 'verein/' in url:
        return url.split('/')[4]
    
    return None

def scrape_transfer_table(transfer_table_soup):
    """
    Scrape data from team transfers HTML table 
    """
    table_records = transfer_table_soup.find("tbody").findAll("tr")
    
    # No rows with player transfers info
    if len(table_records[0].findAll("td")) <= 1:
        return None
    
    records = []
    for rec in table_records:
        rec_data = {}
        try:
            rec_data['player_name'] = rec.find("td").find("div").text.strip()
            rec_data['player_id'] = rec.find("td").find("div").find("a")["href"].split("spieler/")[-1]
            rec_data['player_age'] = rec.find("td", class_ = "zentriert alter-transfer-cell").text.strip()
            
            # player nationalities
            nationalities = rec_data['player_nat'] = rec.find(
                "td",
                class_ = "zentriert nat-transfer-cell"
            ).findAll("img")
            rec_data['player_nat'] = [nat['title'].strip() for nat in nationalities]
        
            rec_data['player_pos'] = rec.find("td", class_ = "kurzpos-transfer-cell zentriert").text.strip()
            rec_data['market_val'] = rec.find("td", class_ = "rechts mw-transfer-cell").text.strip()
            
            # counter team data
            counter_team = rec.find("td", class_ = "verein-flagge-transfer-cell")
            rec_data['counter_team_country'] = counter_team.find("img")["title"].strip() if counter_team.find("img") else counter_team.text.strip()
            rec_data['counter_team_name'] = counter_team.find("a")["title"].strip() if counter_team.find("a") else counter_team.text.strip()
            rec_data['counter_team_id'] = parse_team_id_from_url(
                counter_team.find("a")["href"]
            ) if counter_team.find("a") else counter_team.text.strip()
            
            # transfer data
            transfer = rec.findAll("td", class_ = "rechts")[-1].find("a")
            rec_data['transfer_fee'] = transfer.text.strip()
            rec_data['transfer_id'] = transfer["href"].split("transfer_id/")[-1]
            
        except Exception as e:
            print(rec)
            raise e
        
        records.append(rec_data)
        
    return records

# %%
def scrape_league_season(session, league, season, window):
    """
    
    """
    league_soup = get_league_html(session, league, season, window)
    league_country = league_soup.find("td", class_="no-border-links verein-flagge-transfer-cell").find("img")['title'].strip()
    
    boxes = league_soup.find_all(class_ = "box")
    team_boxes = []
    for box in boxes:
        if box.find("h2", class_ = "content-box-headline content-box-headline--inverted content-box-headline--logo"): # transfer-zusatzinfo-box
            team_boxes.append(box)
            
    data = []
    for box in team_boxes:
        # team name and ID

        # OLD
        #team_info_tag = box.find("div", class_ = "table-header")
        #team_id = box['id'].split('-')[1]

        # WORKING
        team_name = box.find("img")['title'].strip()
        team_id = re.findall('id="to-'+ "(.*?)" +'">', str(box))[0]
        
        # Log
        print(f"TEAM {team_name}, ID {team_id}")

        # Tables with transfers
        team_tables = box.find_all("table")

        # IN transfers
        in_transfers = scrape_transfer_table(team_tables[0])

        # OUT transfers
        out_transfers = scrape_transfer_table(team_tables[1])

        data.append(
            {
                'team': {
                    'team_name': team_name,
                    'team_id': team_id,
                    'team_country': league_country
                },
                'in': in_transfers,
                'left': out_transfers
            }
        )
        
    return data

# %%
def scrape_script(leagues:list=['GB1', 'ES1', 'IT1', 'L1', 'FR1', 'PO1', 'NL1'], seasons:list=[2022, 2023, 2024], windows:list=["s", "w"]):
    HEADERS = {
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
        'accept-encoding': 'gzip, deflate, br',
        'accept-language': 'ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7',
        'cache-control': 'max-age=0',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.142 Safari/537.36 OPR/62.0.3331.116',
    }
    
    SCRAPE_LEAGUES = leagues
    SCRAPE_SEASONS = seasons
    SCRAPE_WINDOWS = windows
    
    session = requests.session()
    session.headers.update(HEADERS)
    
    for league in SCRAPE_LEAGUES:
        for season in SCRAPE_SEASONS:
            for window in SCRAPE_WINDOWS:
            
                time.sleep(15)
                print('SCRAPE:', league, season, window)
                try:
                    data = scrape_league_season(session, league, season, window)
                except:
                    print("Data not avaible")

                filename = 'data/{league}_{season}_{window}.json'.format(
                    league=league,
                    season=season,
                    window=window
                )
                
                with open(filename, 'w', encoding='utf8') as output:
                    json.dump(data, output, ensure_ascii=False)
                
                
    return None

# %% [markdown]
# ### RUN SCRAPER

# %% [markdown]
# **Test**

# %%
# scrape_script(leagues=['GB1'], seasons=[2022], windows=["s", "w"])

# %% [markdown]
# **All leagues**

# %%
scrape_script()
# Out:
# SCRAPE: GB1 2022 s
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/GB1/plus/?saison_id=2022&s_w=s
# RESP
# <Response [200]>
# TEAM Arsenal FC, ID 11
# TEAM Aston Villa, ID 405
# TEAM AFC Bournemouth, ID 989
# TEAM Brentford FC, ID 1148
# TEAM Brighton & Hove Albion, ID 1237
# TEAM Chelsea FC, ID 631
# TEAM Crystal Palace, ID 873
# TEAM Everton FC, ID 29
# TEAM Fulham FC, ID 931
# TEAM Leeds United, ID 399
# TEAM Leicester City, ID 1003
# TEAM Liverpool FC, ID 31
# TEAM Manchester City, ID 281
# TEAM Manchester United, ID 985
# TEAM Newcastle United, ID 762
# TEAM Nottingham Forest, ID 703
# TEAM Southampton FC, ID 180
# TEAM Tottenham Hotspur, ID 148
# TEAM West Ham United, ID 379
# TEAM Wolverhampton Wanderers, ID 543
# SCRAPE: GB1 2022 w
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/GB1/plus/?saison_id=2022&s_w=w
# RESP
# <Response [200]>
# TEAM Arsenal FC, ID 11
# TEAM Aston Villa, ID 405
# TEAM AFC Bournemouth, ID 989
# TEAM Brentford FC, ID 1148
# TEAM Brighton & Hove Albion, ID 1237
# TEAM Chelsea FC, ID 631
# TEAM Crystal Palace, ID 873
# TEAM Everton FC, ID 29
# TEAM Fulham FC, ID 931
# TEAM Leeds United, ID 399
# TEAM Leicester City, ID 1003
# TEAM Liverpool FC, ID 31
# TEAM Manchester City, ID 281
# TEAM Manchester United, ID 985
# TEAM Newcastle United, ID 762
# TEAM Nottingham Forest, ID 703
# TEAM Southampton FC, ID 180
# TEAM Tottenham Hotspur, ID 148
# TEAM West Ham United, ID 379
# TEAM Wolverhampton Wanderers, ID 543
# SCRAPE: GB1 2023 s
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/GB1/plus/?saison_id=2023&s_w=s
# RESP
# <Response [200]>
# TEAM Arsenal FC, ID 11
# TEAM Aston Villa, ID 405
# TEAM AFC Bournemouth, ID 989
# TEAM Brentford FC, ID 1148
# TEAM Brighton & Hove Albion, ID 1237
# TEAM Burnley FC, ID 1132
# TEAM Chelsea FC, ID 631
# TEAM Crystal Palace, ID 873
# TEAM Everton FC, ID 29
# TEAM Fulham FC, ID 931
# TEAM Liverpool FC, ID 31
# TEAM Luton Town, ID 1031
# TEAM Manchester City, ID 281
# TEAM Manchester United, ID 985
# TEAM Newcastle United, ID 762
# TEAM Nottingham Forest, ID 703
# TEAM Sheffield United, ID 350
# TEAM Tottenham Hotspur, ID 148
# TEAM West Ham United, ID 379
# TEAM Wolverhampton Wanderers, ID 543
# SCRAPE: GB1 2023 w
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/GB1/plus/?saison_id=2023&s_w=w
# RESP
# <Response [200]>
# TEAM Arsenal FC, ID 11
# TEAM Aston Villa, ID 405
# TEAM AFC Bournemouth, ID 989
# TEAM Brentford FC, ID 1148
# TEAM Brighton & Hove Albion, ID 1237
# TEAM Burnley FC, ID 1132
# TEAM Chelsea FC, ID 631
# TEAM Crystal Palace, ID 873
# TEAM Everton FC, ID 29
# TEAM Fulham FC, ID 931
# TEAM Liverpool FC, ID 31
# TEAM Luton Town, ID 1031
# TEAM Manchester City, ID 281
# TEAM Manchester United, ID 985
# TEAM Newcastle United, ID 762
# TEAM Nottingham Forest, ID 703
# TEAM Sheffield United, ID 350
# TEAM Tottenham Hotspur, ID 148
# TEAM West Ham United, ID 379
# TEAM Wolverhampton Wanderers, ID 543
# SCRAPE: GB1 2024 s
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/GB1/plus/?saison_id=2024&s_w=s
# RESP
# <Response [200]>
# TEAM Arsenal FC, ID 11
# TEAM Aston Villa, ID 405
# TEAM AFC Bournemouth, ID 989
# TEAM Brentford FC, ID 1148
# TEAM Brighton & Hove Albion, ID 1237
# TEAM Burnley FC, ID 1132
# TEAM Chelsea FC, ID 631
# TEAM Crystal Palace, ID 873
# TEAM Everton FC, ID 29
# TEAM Fulham FC, ID 931
# TEAM Liverpool FC, ID 31
# TEAM Luton Town, ID 1031
# TEAM Manchester City, ID 281
# TEAM Manchester United, ID 985
# TEAM Newcastle United, ID 762
# TEAM Nottingham Forest, ID 703
# TEAM Sheffield United, ID 350
# TEAM Tottenham Hotspur, ID 148
# TEAM West Ham United, ID 379
# TEAM Wolverhampton Wanderers, ID 543
# SCRAPE: GB1 2024 w
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/GB1/plus/?saison_id=2024&s_w=w
# RESP
# <Response [200]>
# TEAM Arsenal FC, ID 11
# TEAM Aston Villa, ID 405
# TEAM AFC Bournemouth, ID 989
# TEAM Brentford FC, ID 1148
# TEAM Brighton & Hove Albion, ID 1237
# TEAM Burnley FC, ID 1132
# TEAM Chelsea FC, ID 631
# TEAM Crystal Palace, ID 873
# TEAM Everton FC, ID 29
# TEAM Fulham FC, ID 931
# TEAM Liverpool FC, ID 31
# TEAM Luton Town, ID 1031
# TEAM Manchester City, ID 281
# TEAM Manchester United, ID 985
# TEAM Newcastle United, ID 762
# TEAM Nottingham Forest, ID 703
# TEAM Sheffield United, ID 350
# TEAM Tottenham Hotspur, ID 148
# TEAM West Ham United, ID 379
# TEAM Wolverhampton Wanderers, ID 543
# SCRAPE: ES1 2022 s
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/ES1/plus/?saison_id=2022&s_w=s
# RESP
# <Response [200]>
# TEAM Real Madrid, ID 418
# TEAM FC Barcelona, ID 131
# TEAM Sevilla FC, ID 368
# TEAM Atlético de Madrid, ID 13
# TEAM Real Sociedad, ID 681
# TEAM Real Betis Balompié, ID 150
# TEAM Villarreal CF, ID 1050
# TEAM Athletic Bilbao, ID 621
# TEAM Valencia CF, ID 1049
# TEAM CA Osasuna, ID 331
# TEAM Elche CF, ID 1531
# TEAM Celta de Vigo, ID 940
# TEAM RCD Espanyol Barcelona, ID 714
# TEAM Rayo Vallecano, ID 367
# TEAM Getafe CF, ID 3709
# TEAM RCD Mallorca, ID 237
# TEAM Cádiz CF, ID 2687
# TEAM UD Almería, ID 3302
# TEAM Real Valladolid CF, ID 366
# TEAM Girona FC, ID 12321
# SCRAPE: ES1 2022 w
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/ES1/plus/?saison_id=2022&s_w=w
# RESP
# <Response [200]>
# TEAM Real Madrid, ID 418
# TEAM FC Barcelona, ID 131
# TEAM Sevilla FC, ID 368
# TEAM Atlético de Madrid, ID 13
# TEAM Real Sociedad, ID 681
# TEAM Real Betis Balompié, ID 150
# TEAM Villarreal CF, ID 1050
# TEAM Athletic Bilbao, ID 621
# TEAM Valencia CF, ID 1049
# TEAM CA Osasuna, ID 331
# TEAM Elche CF, ID 1531
# TEAM Celta de Vigo, ID 940
# TEAM RCD Espanyol Barcelona, ID 714
# TEAM Rayo Vallecano, ID 367
# TEAM Getafe CF, ID 3709
# TEAM RCD Mallorca, ID 237
# TEAM Cádiz CF, ID 2687
# TEAM UD Almería, ID 3302
# TEAM Real Valladolid CF, ID 366
# TEAM Girona FC, ID 12321
# SCRAPE: ES1 2023 s
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/ES1/plus/?saison_id=2023&s_w=s
# RESP
# <Response [200]>
# TEAM Athletic Bilbao, ID 621
# TEAM Atlético de Madrid, ID 13
# TEAM FC Barcelona, ID 131
# TEAM Girona FC, ID 12321
# TEAM CA Osasuna, ID 331
# TEAM Real Betis Balompié, ID 150
# TEAM Real Madrid, ID 418
# TEAM Real Sociedad, ID 681
# TEAM Sevilla FC, ID 368
# TEAM Villarreal CF, ID 1050
# TEAM Granada CF, ID 16795
# TEAM UD Las Palmas, ID 472
# TEAM Rayo Vallecano, ID 367
# TEAM RCD Mallorca, ID 237
# TEAM Getafe CF, ID 3709
# TEAM Valencia CF, ID 1049
# TEAM UD Almería, ID 3302
# TEAM Celta de Vigo, ID 940
# TEAM Cádiz CF, ID 2687
# TEAM Deportivo Alavés, ID 1108
# SCRAPE: ES1 2023 w
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/ES1/plus/?saison_id=2023&s_w=w
# RESP
# <Response [200]>
# TEAM Athletic Bilbao, ID 621
# TEAM Atlético de Madrid, ID 13
# TEAM FC Barcelona, ID 131
# TEAM Girona FC, ID 12321
# TEAM CA Osasuna, ID 331
# TEAM Real Betis Balompié, ID 150
# TEAM Real Madrid, ID 418
# TEAM Real Sociedad, ID 681
# TEAM Sevilla FC, ID 368
# TEAM Villarreal CF, ID 1050
# TEAM Granada CF, ID 16795
# TEAM UD Las Palmas, ID 472
# TEAM Rayo Vallecano, ID 367
# TEAM RCD Mallorca, ID 237
# TEAM Getafe CF, ID 3709
# TEAM Valencia CF, ID 1049
# TEAM UD Almería, ID 3302
# TEAM Celta de Vigo, ID 940
# TEAM Cádiz CF, ID 2687
# TEAM Deportivo Alavés, ID 1108
# SCRAPE: ES1 2024 s
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/ES1/plus/?saison_id=2024&s_w=s
# RESP
# <Response [200]>
# TEAM Athletic Bilbao, ID 621
# TEAM Atlético de Madrid, ID 13
# TEAM FC Barcelona, ID 131
# TEAM Girona FC, ID 12321
# TEAM CA Osasuna, ID 331
# TEAM Real Betis Balompié, ID 150
# TEAM Real Madrid, ID 418
# TEAM Real Sociedad, ID 681
# TEAM Sevilla FC, ID 368
# TEAM Villarreal CF, ID 1050
# TEAM Granada CF, ID 16795
# TEAM UD Las Palmas, ID 472
# TEAM Rayo Vallecano, ID 367
# TEAM RCD Mallorca, ID 237
# TEAM Getafe CF, ID 3709
# TEAM Valencia CF, ID 1049
# TEAM UD Almería, ID 3302
# TEAM Celta de Vigo, ID 940
# TEAM Cádiz CF, ID 2687
# TEAM Deportivo Alavés, ID 1108
# SCRAPE: ES1 2024 w
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/ES1/plus/?saison_id=2024&s_w=w
# RESP
# <Response [200]>
# TEAM Athletic Bilbao, ID 621
# TEAM Atlético de Madrid, ID 13
# TEAM FC Barcelona, ID 131
# TEAM Girona FC, ID 12321
# TEAM CA Osasuna, ID 331
# TEAM Real Betis Balompié, ID 150
# TEAM Real Madrid, ID 418
# TEAM Real Sociedad, ID 681
# TEAM Sevilla FC, ID 368
# TEAM Villarreal CF, ID 1050
# TEAM Granada CF, ID 16795
# TEAM UD Las Palmas, ID 472
# TEAM Rayo Vallecano, ID 367
# TEAM RCD Mallorca, ID 237
# TEAM Getafe CF, ID 3709
# TEAM Valencia CF, ID 1049
# TEAM UD Almería, ID 3302
# TEAM Celta de Vigo, ID 940
# TEAM Cádiz CF, ID 2687
# TEAM Deportivo Alavés, ID 1108
# SCRAPE: IT1 2022 s
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/IT1/plus/?saison_id=2022&s_w=s
# RESP
# <Response [200]>
# TEAM AC Milan, ID 5
# TEAM Inter Milan, ID 46
# TEAM SSC Napoli, ID 6195
# TEAM Juventus FC, ID 506
# TEAM SS Lazio, ID 398
# TEAM AS Roma, ID 12
# TEAM ACF Fiorentina, ID 430
# TEAM Atalanta BC, ID 800
# TEAM Hellas Verona, ID 276
# TEAM Torino FC, ID 416
# TEAM US Sassuolo, ID 6574
# TEAM Udinese Calcio, ID 410
# TEAM Bologna FC 1909, ID 1025
# TEAM FC Empoli, ID 749
# TEAM UC Sampdoria, ID 1038
# TEAM , ID 3522
# TEAM US Salernitana 1919, ID 380
# TEAM US Lecce, ID 1005
# TEAM US Cremonese, ID 2239
# TEAM AC Monza, ID 2919
# SCRAPE: IT1 2022 w
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/IT1/plus/?saison_id=2022&s_w=w
# RESP
# <Response [200]>
# TEAM AC Milan, ID 5
# TEAM Inter Milan, ID 46
# TEAM SSC Napoli, ID 6195
# TEAM Juventus FC, ID 506
# TEAM SS Lazio, ID 398
# TEAM AS Roma, ID 12
# TEAM ACF Fiorentina, ID 430
# TEAM Atalanta BC, ID 800
# TEAM Hellas Verona, ID 276
# TEAM Torino FC, ID 416
# TEAM US Sassuolo, ID 6574
# TEAM Udinese Calcio, ID 410
# TEAM Bologna FC 1909, ID 1025
# TEAM FC Empoli, ID 749
# TEAM UC Sampdoria, ID 1038
# TEAM , ID 3522
# TEAM US Salernitana 1919, ID 380
# TEAM US Lecce, ID 1005
# TEAM US Cremonese, ID 2239
# TEAM AC Monza, ID 2919
# SCRAPE: IT1 2023 s
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/IT1/plus/?saison_id=2023&s_w=s
# RESP
# <Response [200]>
# TEAM SSC Napoli, ID 6195
# TEAM SS Lazio, ID 398
# TEAM Inter Milan, ID 46
# TEAM AC Milan, ID 5
# TEAM Atalanta BC, ID 800
# TEAM AS Roma, ID 12
# TEAM Juventus FC, ID 506
# TEAM ACF Fiorentina, ID 430
# TEAM Bologna FC 1909, ID 1025
# TEAM Torino FC, ID 416
# TEAM AC Monza, ID 2919
# TEAM Udinese Calcio, ID 410
# TEAM US Sassuolo, ID 6574
# TEAM FC Empoli, ID 749
# TEAM US Salernitana 1919, ID 380
# TEAM US Lecce, ID 1005
# TEAM Hellas Verona, ID 276
# TEAM Frosinone Calcio, ID 8970
# TEAM Genoa CFC, ID 252
# TEAM Cagliari Calcio, ID 1390
# SCRAPE: IT1 2023 w
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/IT1/plus/?saison_id=2023&s_w=w
# RESP
# <Response [200]>
# TEAM SSC Napoli, ID 6195
# TEAM SS Lazio, ID 398
# TEAM Inter Milan, ID 46
# TEAM AC Milan, ID 5
# TEAM Atalanta BC, ID 800
# TEAM AS Roma, ID 12
# TEAM Juventus FC, ID 506
# TEAM ACF Fiorentina, ID 430
# TEAM Bologna FC 1909, ID 1025
# TEAM Torino FC, ID 416
# TEAM AC Monza, ID 2919
# TEAM Udinese Calcio, ID 410
# TEAM US Sassuolo, ID 6574
# TEAM FC Empoli, ID 749
# TEAM US Salernitana 1919, ID 380
# TEAM US Lecce, ID 1005
# TEAM Hellas Verona, ID 276
# TEAM Frosinone Calcio, ID 8970
# TEAM Genoa CFC, ID 252
# TEAM Cagliari Calcio, ID 1390
# SCRAPE: IT1 2024 s
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/IT1/plus/?saison_id=2024&s_w=s
# RESP
# <Response [200]>
# TEAM SSC Napoli, ID 6195
# TEAM SS Lazio, ID 398
# TEAM Inter Milan, ID 46
# TEAM AC Milan, ID 5
# TEAM Atalanta BC, ID 800
# TEAM AS Roma, ID 12
# TEAM Juventus FC, ID 506
# TEAM ACF Fiorentina, ID 430
# TEAM Bologna FC 1909, ID 1025
# TEAM Torino FC, ID 416
# TEAM AC Monza, ID 2919
# TEAM Udinese Calcio, ID 410
# TEAM US Sassuolo, ID 6574
# TEAM FC Empoli, ID 749
# TEAM US Salernitana 1919, ID 380
# TEAM US Lecce, ID 1005
# TEAM Hellas Verona, ID 276
# TEAM Frosinone Calcio, ID 8970
# TEAM Genoa CFC, ID 252
# TEAM Cagliari Calcio, ID 1390
# SCRAPE: IT1 2024 w
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/IT1/plus/?saison_id=2024&s_w=w
# RESP
# <Response [200]>
# Data not avaible
# SCRAPE: L1 2022 s
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/L1/plus/?saison_id=2022&s_w=s
# RESP
# <Response [200]>
# TEAM Bayern Munich, ID 27
# TEAM Borussia Dortmund, ID 16
# TEAM Bayer 04 Leverkusen, ID 15
# TEAM RB Leipzig, ID 23826
# TEAM 1.FC Union Berlin, ID 89
# TEAM SC Freiburg, ID 60
# TEAM 1.FC Köln, ID 3
# TEAM 1.FSV Mainz 05, ID 39
# TEAM TSG 1899 Hoffenheim, ID 533
# TEAM Borussia Mönchengladbach, ID 18
# TEAM Eintracht Frankfurt, ID 24
# TEAM VfL Wolfsburg, ID 82
# TEAM VfL Bochum, ID 80
# TEAM FC Augsburg, ID 167
# TEAM VfB Stuttgart, ID 79
# TEAM Hertha BSC, ID 44
# TEAM FC Schalke 04, ID 33
# TEAM SV Werder Bremen, ID 86
# SCRAPE: L1 2022 w
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/L1/plus/?saison_id=2022&s_w=w
# RESP
# <Response [200]>
# TEAM Bayern Munich, ID 27
# TEAM Borussia Dortmund, ID 16
# TEAM Bayer 04 Leverkusen, ID 15
# TEAM RB Leipzig, ID 23826
# TEAM 1.FC Union Berlin, ID 89
# TEAM SC Freiburg, ID 60
# TEAM 1.FC Köln, ID 3
# TEAM 1.FSV Mainz 05, ID 39
# TEAM TSG 1899 Hoffenheim, ID 533
# TEAM Borussia Mönchengladbach, ID 18
# TEAM Eintracht Frankfurt, ID 24
# TEAM VfL Wolfsburg, ID 82
# TEAM VfL Bochum, ID 80
# TEAM FC Augsburg, ID 167
# TEAM VfB Stuttgart, ID 79
# TEAM Hertha BSC, ID 44
# TEAM FC Schalke 04, ID 33
# TEAM SV Werder Bremen, ID 86
# SCRAPE: L1 2023 s
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/L1/plus/?saison_id=2023&s_w=s
# RESP
# <Response [200]>
# TEAM Bayern Munich, ID 27
# TEAM Borussia Dortmund, ID 16
# TEAM RB Leipzig, ID 23826
# TEAM 1.FC Union Berlin, ID 89
# TEAM SC Freiburg, ID 60
# TEAM Bayer 04 Leverkusen, ID 15
# TEAM Eintracht Frankfurt, ID 24
# TEAM VfL Wolfsburg, ID 82
# TEAM 1.FSV Mainz 05, ID 39
# TEAM Borussia Mönchengladbach, ID 18
# TEAM 1.FC Köln, ID 3
# TEAM TSG 1899 Hoffenheim, ID 533
# TEAM SV Werder Bremen, ID 86
# TEAM VfL Bochum, ID 80
# TEAM FC Augsburg, ID 167
# TEAM VfB Stuttgart, ID 79
# TEAM 1.FC Heidenheim 1846, ID 2036
# TEAM SV Darmstadt 98, ID 105
# SCRAPE: L1 2023 w
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/L1/plus/?saison_id=2023&s_w=w
# RESP
# <Response [200]>
# TEAM Bayern Munich, ID 27
# TEAM Borussia Dortmund, ID 16
# TEAM RB Leipzig, ID 23826
# TEAM 1.FC Union Berlin, ID 89
# TEAM SC Freiburg, ID 60
# TEAM Bayer 04 Leverkusen, ID 15
# TEAM Eintracht Frankfurt, ID 24
# TEAM VfL Wolfsburg, ID 82
# TEAM 1.FSV Mainz 05, ID 39
# TEAM Borussia Mönchengladbach, ID 18
# TEAM 1.FC Köln, ID 3
# TEAM TSG 1899 Hoffenheim, ID 533
# TEAM SV Werder Bremen, ID 86
# TEAM VfL Bochum, ID 80
# TEAM FC Augsburg, ID 167
# TEAM VfB Stuttgart, ID 79
# TEAM 1.FC Heidenheim 1846, ID 2036
# TEAM SV Darmstadt 98, ID 105
# SCRAPE: L1 2024 s
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/L1/plus/?saison_id=2024&s_w=s
# RESP
# <Response [200]>
# TEAM Bayern Munich, ID 27
# TEAM Borussia Dortmund, ID 16
# TEAM RB Leipzig, ID 23826
# TEAM 1.FC Union Berlin, ID 89
# TEAM SC Freiburg, ID 60
# TEAM Bayer 04 Leverkusen, ID 15
# TEAM Eintracht Frankfurt, ID 24
# TEAM VfL Wolfsburg, ID 82
# TEAM 1.FSV Mainz 05, ID 39
# TEAM Borussia Mönchengladbach, ID 18
# TEAM 1.FC Köln, ID 3
# TEAM TSG 1899 Hoffenheim, ID 533
# TEAM SV Werder Bremen, ID 86
# TEAM VfL Bochum, ID 80
# TEAM FC Augsburg, ID 167
# TEAM VfB Stuttgart, ID 79
# TEAM 1.FC Heidenheim 1846, ID 2036
# TEAM SV Darmstadt 98, ID 105
# SCRAPE: L1 2024 w
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/L1/plus/?saison_id=2024&s_w=w
# RESP
# <Response [200]>
# TEAM Bayern Munich, ID 27
# TEAM Borussia Dortmund, ID 16
# TEAM RB Leipzig, ID 23826
# TEAM 1.FC Union Berlin, ID 89
# TEAM SC Freiburg, ID 60
# TEAM Bayer 04 Leverkusen, ID 15
# TEAM Eintracht Frankfurt, ID 24
# TEAM VfL Wolfsburg, ID 82
# TEAM 1.FSV Mainz 05, ID 39
# TEAM Borussia Mönchengladbach, ID 18
# TEAM 1.FC Köln, ID 3
# TEAM TSG 1899 Hoffenheim, ID 533
# TEAM SV Werder Bremen, ID 86
# TEAM VfL Bochum, ID 80
# TEAM FC Augsburg, ID 167
# TEAM VfB Stuttgart, ID 79
# TEAM 1.FC Heidenheim 1846, ID 2036
# TEAM SV Darmstadt 98, ID 105
# SCRAPE: FR1 2022 s
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/FR1/plus/?saison_id=2022&s_w=s
# RESP
# <Response [200]>
# TEAM Paris Saint-Germain, ID 583
# TEAM Olympique Marseille, ID 244
# TEAM AS Monaco, ID 162
# TEAM Stade Rennais FC, ID 273
# TEAM OGC Nice, ID 417
# TEAM RC Strasbourg Alsace, ID 667
# TEAM RC Lens, ID 826
# TEAM Olympique Lyon, ID 1041
# TEAM FC Nantes, ID 995
# TEAM LOSC Lille, ID 1082
# TEAM Stade Brestois 29, ID 3911
# TEAM Stade Reims, ID 1421
# TEAM Montpellier HSC, ID 969
# TEAM Angers SCO, ID 1420
# TEAM ESTAC Troyes, ID 1095
# TEAM FC Lorient, ID 1158
# TEAM Clermont Foot 63, ID 3524
# TEAM FC Toulouse, ID 415
# TEAM AC Ajaccio, ID 1147
# TEAM AJ Auxerre, ID 290
# SCRAPE: FR1 2022 w
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/FR1/plus/?saison_id=2022&s_w=w
# RESP
# <Response [200]>
# TEAM Paris Saint-Germain, ID 583
# TEAM Olympique Marseille, ID 244
# TEAM AS Monaco, ID 162
# TEAM Stade Rennais FC, ID 273
# TEAM OGC Nice, ID 417
# TEAM RC Strasbourg Alsace, ID 667
# TEAM RC Lens, ID 826
# TEAM Olympique Lyon, ID 1041
# TEAM FC Nantes, ID 995
# TEAM LOSC Lille, ID 1082
# TEAM Stade Brestois 29, ID 3911
# TEAM Stade Reims, ID 1421
# TEAM Montpellier HSC, ID 969
# TEAM Angers SCO, ID 1420
# TEAM ESTAC Troyes, ID 1095
# TEAM FC Lorient, ID 1158
# TEAM Clermont Foot 63, ID 3524
# TEAM FC Toulouse, ID 415
# TEAM AC Ajaccio, ID 1147
# TEAM AJ Auxerre, ID 290
# SCRAPE: FR1 2023 s
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/FR1/plus/?saison_id=2023&s_w=s
# RESP
# <Response [200]>
# TEAM Paris Saint-Germain, ID 583
# TEAM RC Lens, ID 826
# TEAM Olympique Marseille, ID 244
# TEAM AS Monaco, ID 162
# TEAM Stade Rennais FC, ID 273
# TEAM LOSC Lille, ID 1082
# TEAM Olympique Lyon, ID 1041
# TEAM Clermont Foot 63, ID 3524
# TEAM OGC Nice, ID 417
# TEAM FC Lorient, ID 1158
# TEAM Stade Reims, ID 1421
# TEAM Montpellier HSC, ID 969
# TEAM FC Toulouse, ID 415
# TEAM Stade Brestois 29, ID 3911
# TEAM RC Strasbourg Alsace, ID 667
# TEAM FC Nantes, ID 995
# TEAM Le Havre AC, ID 738
# TEAM FC Metz, ID 347
# SCRAPE: FR1 2023 w
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/FR1/plus/?saison_id=2023&s_w=w
# RESP
# <Response [200]>
# TEAM Paris Saint-Germain, ID 583
# TEAM RC Lens, ID 826
# TEAM Olympique Marseille, ID 244
# TEAM AS Monaco, ID 162
# TEAM Stade Rennais FC, ID 273
# TEAM LOSC Lille, ID 1082
# TEAM Olympique Lyon, ID 1041
# TEAM Clermont Foot 63, ID 3524
# TEAM OGC Nice, ID 417
# TEAM FC Lorient, ID 1158
# TEAM Stade Reims, ID 1421
# TEAM Montpellier HSC, ID 969
# TEAM FC Toulouse, ID 415
# TEAM Stade Brestois 29, ID 3911
# TEAM RC Strasbourg Alsace, ID 667
# TEAM FC Nantes, ID 995
# TEAM Le Havre AC, ID 738
# TEAM FC Metz, ID 347
# SCRAPE: FR1 2024 s
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/FR1/plus/?saison_id=2024&s_w=s
# RESP
# <Response [200]>
# TEAM Paris Saint-Germain, ID 583
# TEAM RC Lens, ID 826
# TEAM Olympique Marseille, ID 244
# TEAM AS Monaco, ID 162
# TEAM Stade Rennais FC, ID 273
# TEAM LOSC Lille, ID 1082
# TEAM Olympique Lyon, ID 1041
# TEAM Clermont Foot 63, ID 3524
# TEAM OGC Nice, ID 417
# TEAM FC Lorient, ID 1158
# TEAM Stade Reims, ID 1421
# TEAM Montpellier HSC, ID 969
# TEAM FC Toulouse, ID 415
# TEAM Stade Brestois 29, ID 3911
# TEAM RC Strasbourg Alsace, ID 667
# TEAM FC Nantes, ID 995
# TEAM Le Havre AC, ID 738
# TEAM FC Metz, ID 347
# SCRAPE: FR1 2024 w
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/FR1/plus/?saison_id=2024&s_w=w
# RESP
# <Response [200]>
# TEAM Paris Saint-Germain, ID 583
# TEAM RC Lens, ID 826
# TEAM Olympique Marseille, ID 244
# TEAM AS Monaco, ID 162
# TEAM Stade Rennais FC, ID 273
# TEAM LOSC Lille, ID 1082
# TEAM Olympique Lyon, ID 1041
# TEAM Clermont Foot 63, ID 3524
# TEAM OGC Nice, ID 417
# TEAM FC Lorient, ID 1158
# TEAM Stade Reims, ID 1421
# TEAM Montpellier HSC, ID 969
# TEAM FC Toulouse, ID 415
# TEAM Stade Brestois 29, ID 3911
# TEAM RC Strasbourg Alsace, ID 667
# TEAM FC Nantes, ID 995
# TEAM Le Havre AC, ID 738
# TEAM FC Metz, ID 347
# SCRAPE: PO1 2022 s
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/PO1/plus/?saison_id=2022&s_w=s
# RESP
# <Response [200]>
# TEAM FC Porto, ID 720
# TEAM Sporting CP, ID 336
# TEAM SL Benfica, ID 294
# TEAM SC Braga, ID 1075
# TEAM Gil Vicente FC, ID 2424
# TEAM Vitória Guimarães SC, ID 2420
# TEAM CD Santa Clara, ID 2423
# TEAM FC Famalicão, ID 3329
# TEAM GD Estoril Praia, ID 1465
# TEAM CS Marítimo, ID 1301
# TEAM FC Paços de Ferreira, ID 2995
# TEAM Boavista FC, ID 2503
# TEAM Portimonense SC, ID 7378
# TEAM FC Vizela, ID 6912
# TEAM FC Arouca, ID 8024
# TEAM Rio Ave FC, ID 2425
# TEAM Casa Pia AC, ID 3268
# TEAM GD Chaves, ID 3325
# SCRAPE: PO1 2022 w
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/PO1/plus/?saison_id=2022&s_w=w
# RESP
# <Response [200]>
# TEAM FC Porto, ID 720
# TEAM Sporting CP, ID 336
# TEAM SL Benfica, ID 294
# TEAM SC Braga, ID 1075
# TEAM Gil Vicente FC, ID 2424
# TEAM Vitória Guimarães SC, ID 2420
# TEAM CD Santa Clara, ID 2423
# TEAM FC Famalicão, ID 3329
# TEAM GD Estoril Praia, ID 1465
# TEAM CS Marítimo, ID 1301
# TEAM FC Paços de Ferreira, ID 2995
# TEAM Boavista FC, ID 2503
# TEAM Portimonense SC, ID 7378
# TEAM FC Vizela, ID 6912
# TEAM FC Arouca, ID 8024
# TEAM Rio Ave FC, ID 2425
# TEAM Casa Pia AC, ID 3268
# TEAM GD Chaves, ID 3325
# SCRAPE: PO1 2023 s
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/PO1/plus/?saison_id=2023&s_w=s
# RESP
# <Response [200]>
# TEAM SL Benfica, ID 294
# TEAM FC Porto, ID 720
# TEAM SC Braga, ID 1075
# TEAM Sporting CP, ID 336
# TEAM FC Arouca, ID 8024
# TEAM Vitória Guimarães SC, ID 2420
# TEAM GD Chaves, ID 3325
# TEAM FC Famalicão, ID 3329
# TEAM Boavista FC, ID 2503
# TEAM Casa Pia AC, ID 3268
# TEAM FC Vizela, ID 6912
# TEAM Rio Ave FC, ID 2425
# TEAM Gil Vicente FC, ID 2424
# TEAM GD Estoril Praia, ID 1465
# TEAM Portimonense SC, ID 7378
# TEAM Moreirense FC, ID 979
# TEAM SC Farense, ID 4294
# TEAM CF Estrela Amadora SAD, ID 2431
# SCRAPE: PO1 2023 w
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/PO1/plus/?saison_id=2023&s_w=w
# RESP
# <Response [200]>
# TEAM SL Benfica, ID 294
# TEAM FC Porto, ID 720
# TEAM SC Braga, ID 1075
# TEAM Sporting CP, ID 336
# TEAM FC Arouca, ID 8024
# TEAM Vitória Guimarães SC, ID 2420
# TEAM GD Chaves, ID 3325
# TEAM FC Famalicão, ID 3329
# TEAM Boavista FC, ID 2503
# TEAM Casa Pia AC, ID 3268
# TEAM FC Vizela, ID 6912
# TEAM Rio Ave FC, ID 2425
# TEAM Gil Vicente FC, ID 2424
# TEAM GD Estoril Praia, ID 1465
# TEAM Portimonense SC, ID 7378
# TEAM Moreirense FC, ID 979
# TEAM SC Farense, ID 4294
# TEAM CF Estrela Amadora SAD, ID 2431
# SCRAPE: PO1 2024 s
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/PO1/plus/?saison_id=2024&s_w=s
# RESP
# <Response [200]>
# TEAM SL Benfica, ID 294
# TEAM FC Porto, ID 720
# TEAM SC Braga, ID 1075
# TEAM Sporting CP, ID 336
# TEAM FC Arouca, ID 8024
# TEAM Vitória Guimarães SC, ID 2420
# TEAM GD Chaves, ID 3325
# TEAM FC Famalicão, ID 3329
# TEAM Boavista FC, ID 2503
# TEAM Casa Pia AC, ID 3268
# TEAM FC Vizela, ID 6912
# TEAM Rio Ave FC, ID 2425
# TEAM Gil Vicente FC, ID 2424
# TEAM GD Estoril Praia, ID 1465
# TEAM Portimonense SC, ID 7378
# TEAM Moreirense FC, ID 979
# TEAM SC Farense, ID 4294
# TEAM CF Estrela Amadora SAD, ID 2431
# SCRAPE: PO1 2024 w
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/PO1/plus/?saison_id=2024&s_w=w
# RESP
# <Response [200]>
# TEAM SL Benfica, ID 294
# TEAM FC Porto, ID 720
# TEAM SC Braga, ID 1075
# TEAM Sporting CP, ID 336
# TEAM FC Arouca, ID 8024
# TEAM Vitória Guimarães SC, ID 2420
# TEAM GD Chaves, ID 3325
# TEAM FC Famalicão, ID 3329
# TEAM Boavista FC, ID 2503
# TEAM Casa Pia AC, ID 3268
# TEAM FC Vizela, ID 6912
# TEAM Rio Ave FC, ID 2425
# TEAM Gil Vicente FC, ID 2424
# TEAM GD Estoril Praia, ID 1465
# TEAM Portimonense SC, ID 7378
# TEAM Moreirense FC, ID 979
# TEAM SC Farense, ID 4294
# TEAM CF Estrela Amadora SAD, ID 2431
# SCRAPE: NL1 2022 s
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/NL1/plus/?saison_id=2022&s_w=s
# RESP
# <Response [200]>
# TEAM Ajax Amsterdam, ID 610
# TEAM AZ Alkmaar, ID 1090
# TEAM SC Cambuur Leeuwarden, ID 133
# TEAM FC Emmen, ID 1283
# TEAM Excelsior Rotterdam, ID 798
# TEAM Feyenoord Rotterdam, ID 234
# TEAM Fortuna Sittard, ID 385
# TEAM Go Ahead Eagles, ID 1435
# TEAM FC Groningen, ID 202
# TEAM SC Heerenveen, ID 306
# TEAM NEC Nijmegen, ID 467
# TEAM PSV Eindhoven, ID 383
# TEAM RKC Waalwijk, ID 235
# TEAM Sparta Rotterdam, ID 468
# TEAM Twente Enschede FC, ID 317
# TEAM FC Utrecht, ID 200
# TEAM Vitesse Arnhem, ID 499
# TEAM FC Volendam, ID 724
# SCRAPE: NL1 2022 w
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/NL1/plus/?saison_id=2022&s_w=w
# RESP
# <Response [200]>
# TEAM Ajax Amsterdam, ID 610
# TEAM AZ Alkmaar, ID 1090
# TEAM SC Cambuur Leeuwarden, ID 133
# TEAM FC Emmen, ID 1283
# TEAM Excelsior Rotterdam, ID 798
# TEAM Feyenoord Rotterdam, ID 234
# TEAM Fortuna Sittard, ID 385
# TEAM Go Ahead Eagles, ID 1435
# TEAM FC Groningen, ID 202
# TEAM SC Heerenveen, ID 306
# TEAM NEC Nijmegen, ID 467
# TEAM PSV Eindhoven, ID 383
# TEAM RKC Waalwijk, ID 235
# TEAM Sparta Rotterdam, ID 468
# TEAM Twente Enschede FC, ID 317
# TEAM FC Utrecht, ID 200
# TEAM Vitesse Arnhem, ID 499
# TEAM FC Volendam, ID 724
# SCRAPE: NL1 2023 s
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/NL1/plus/?saison_id=2023&s_w=s
# RESP
# <Response [200]>
# TEAM Ajax Amsterdam, ID 610
# TEAM Almere City FC, ID 723
# TEAM AZ Alkmaar, ID 1090
# TEAM Excelsior Rotterdam, ID 798
# TEAM Feyenoord Rotterdam, ID 234
# TEAM Fortuna Sittard, ID 385
# TEAM Go Ahead Eagles, ID 1435
# TEAM SC Heerenveen, ID 306
# TEAM Heracles Almelo, ID 1304
# TEAM NEC Nijmegen, ID 467
# TEAM PEC Zwolle, ID 1269
# TEAM PSV Eindhoven, ID 383
# TEAM RKC Waalwijk, ID 235
# TEAM Sparta Rotterdam, ID 468
# TEAM Twente Enschede FC, ID 317
# TEAM FC Utrecht, ID 200
# TEAM Vitesse Arnhem, ID 499
# TEAM FC Volendam, ID 724
# SCRAPE: NL1 2023 w
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/NL1/plus/?saison_id=2023&s_w=w
# RESP
# <Response [200]>
# TEAM Ajax Amsterdam, ID 610
# TEAM Almere City FC, ID 723
# TEAM AZ Alkmaar, ID 1090
# TEAM Excelsior Rotterdam, ID 798
# TEAM Feyenoord Rotterdam, ID 234
# TEAM Fortuna Sittard, ID 385
# TEAM Go Ahead Eagles, ID 1435
# TEAM SC Heerenveen, ID 306
# TEAM Heracles Almelo, ID 1304
# TEAM NEC Nijmegen, ID 467
# TEAM PEC Zwolle, ID 1269
# TEAM PSV Eindhoven, ID 383
# TEAM RKC Waalwijk, ID 235
# TEAM Sparta Rotterdam, ID 468
# TEAM Twente Enschede FC, ID 317
# TEAM FC Utrecht, ID 200
# TEAM Vitesse Arnhem, ID 499
# TEAM FC Volendam, ID 724
# SCRAPE: NL1 2024 s
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/NL1/plus/?saison_id=2024&s_w=s
# RESP
# <Response [200]>
# TEAM Ajax Amsterdam, ID 610
# TEAM Almere City FC, ID 723
# TEAM AZ Alkmaar, ID 1090
# TEAM Excelsior Rotterdam, ID 798
# TEAM Feyenoord Rotterdam, ID 234
# TEAM Fortuna Sittard, ID 385
# TEAM Go Ahead Eagles, ID 1435
# TEAM SC Heerenveen, ID 306
# TEAM Heracles Almelo, ID 1304
# TEAM NEC Nijmegen, ID 467
# TEAM PEC Zwolle, ID 1269
# TEAM PSV Eindhoven, ID 383
# TEAM RKC Waalwijk, ID 235
# TEAM Sparta Rotterdam, ID 468
# TEAM Twente Enschede FC, ID 317
# TEAM FC Utrecht, ID 200
# TEAM Vitesse Arnhem, ID 499
# TEAM FC Volendam, ID 724
# SCRAPE: NL1 2024 w
# URL
# https://www.transfermarkt.com/premier-league/transfers/wettbewerb/NL1/plus/?saison_id=2024&s_w=w
# RESP
# <Response [200]>
# TEAM Ajax Amsterdam, ID 610
# TEAM Almere City FC, ID 723
# TEAM AZ Alkmaar, ID 1090
# TEAM Excelsior Rotterdam, ID 798
# TEAM Feyenoord Rotterdam, ID 234
# TEAM Fortuna Sittard, ID 385
# TEAM Go Ahead Eagles, ID 1435
# TEAM SC Heerenveen, ID 306
# TEAM Heracles Almelo, ID 1304
# TEAM NEC Nijmegen, ID 467
# TEAM PEC Zwolle, ID 1269
# TEAM PSV Eindhoven, ID 383
# TEAM RKC Waalwijk, ID 235
# TEAM Sparta Rotterdam, ID 468
# TEAM Twente Enschede FC, ID 317
# TEAM FC Utrecht, ID 200
# TEAM Vitesse Arnhem, ID 499
# TEAM FC Volendam, ID 724
